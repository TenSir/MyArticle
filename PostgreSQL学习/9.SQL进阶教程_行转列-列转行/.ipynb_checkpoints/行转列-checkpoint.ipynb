# %%
import pandas as pd
data = {
    'Date': ['2021-01-01', '2021-01-02', '2021-01-03'],
    'Product1': [100, 200, 300],
    'Product2': [150, 250, 350]
}
df = pd.DataFrame(data)
df
# Out:
#          Date  Product1  Product2
# 0  2021-01-01       100       150
# 1  2021-01-02       200       250
# 2  2021-01-03       300       350

# %%
product_list = df.columns[1:].tolist()
product_list
# Out:
# ['Product1', 'Product2']

# %%
unpivoted_df = df.melt(id_vars=['Date'], value_vars=product_list, var_name='Product', value_name='Sales')

unpivoted_df
# Out:
#          Date   Product  Sales
# 0  2021-01-01  Product1    100
# 1  2021-01-02  Product1    200
# 2  2021-01-03  Product1    300
# 3  2021-01-01  Product2    150
# 4  2021-01-02  Product2    250
# 5  2021-01-03  Product2    350

# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine, text
# 连接数据库取数
engine = create_engine('postgresql+psycopg2://postgres:123456@127.0.0.1:5432/sql_advanced') 
df = pd.read_sql_query('SELECT * FROM test_hl', engine)

# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine, text
# 连接数据库取数
engine = create_engine('postgresql+psycopg2://postgres:123456@127.0.0.1:5432/sql_advanced') 
df = pd.read_sql_query('SELECT * FROM test_hl', engine) 
df
# Out:
#    id subject  score
# 0  小红      语文     96
# 1  小红      数学     97
# 2  小红      外语     98
# 3  小明      语文     94
# 4  小明      数学     85
# 5  小明      外语     96
# 6  小蓝      数学     97
# 7  小蓝      外语     98
# 8  小蓝      语文     98

# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine, text
# 连接数据库取数
engine = create_engine('postgresql+psycopg2://postgres:123456@127.0.0.1:5432/sql_advanced') 
df = pd.read_sql_query('SELECT * FROM test_hl', engine)

# %%
import pandas as pd

# 创建你的数据
data = {
    'id': ['小红', '小红', '小红', '小明', '小明', '小明', '小蓝', '小蓝', '小蓝'],
    'subject': ['语文', '数学', '外语', '语文', '数学', '外语', '数学', '外语', '语文'],
    'score': [96, 97, 98, 94, 85, 96, 97, 98, 98]
}

df = pd.DataFrame(data)

# 使用 pivot 将行转为列
pivot_df = df.pivot(index='id', columns='subject', values='score')

pivot_df
# Out:
# subject  外语  数学  语文
# id
# 小明       96  85  94
# 小红       98  97  96
# 小蓝       98  97  98

# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine, text
# 连接数据库取数
engine = create_engine('postgresql+psycopg2://postgres:123456@127.0.0.1:5432/sql_advanced') 
df = pd.read_sql_query('SELECT * FROM test_hl', engine) 


# 使用 pivot_table 函数将行数据转换为列数据
result = df.pivot_table(index='id', columns='subject', values='score')

# 如果你想要与 PostgreSQL 中的结果一样，可以重命名列名
result.columns = [f'{col[1]}_{col[0]}' for col in result.columns]

# 删除索引的名称
result.index.name = None

result
# Out:
#      语_外   学_数   文_语
# 小明  96.0  85.0  94.0
# 小红  98.0  97.0  96.0
# 小蓝  98.0  97.0  98.0

# %%
result.index
# Out:
# Index(['小明', '小红', '小蓝'], dtype='object', name='id')

# %%
import pandas as pd

# 创建一个示例 DataFrame

data = {
    'Date': ['2021-01-01', '2021-01-02', '2021-01-03'],
    'Product1': [100, 200, 300],
    'Product2': [150, 250, 350]
}
df = pd.DataFrame(data)
df
# Out:
#          Date  Product1  Product2
# 0  2021-01-01       100       150
# 1  2021-01-02       200       250
# 2  2021-01-03       300       350

# %%
product_list = df.columns[1:].tolist()
unpivoted_df = df.melt(id_vars=['Date'], value_vars=product_list, var_name='Product', value_name='Sales')
unpivoted_df
# Out:
#          Date   Product  Sales
# 0  2021-01-01  Product1    100
# 1  2021-01-02  Product1    200
# 2  2021-01-03  Product1    300
# 3  2021-01-01  Product2    150
# 4  2021-01-02  Product2    250
# 5  2021-01-03  Product2    350
